# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl

# %%
df = pd.read_csv("Q7 assingment done.csv")

# %%
df.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh  Unnamed: 4  Unnamed: 5  \
# 0          Mazda RX4    3.90  2.620  16.46         NaN         NaN
# 1      Mazda RX4 Wag    3.90  2.875  17.02         NaN         NaN
# 2         Datsun 710    3.85  2.320  18.61         NaN         NaN
# 3     Hornet 4 Drive    3.08  3.215  19.44         NaN         NaN
# 4  Hornet Sportabout    3.15  3.440  17.02         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11  \
# 0         NaN         NaN         NaN         NaN          NaN         NaN
# 1         NaN         NaN         NaN         NaN          NaN         NaN
# 2         NaN         NaN         NaN         NaN          NaN         NaN
# 3         NaN         NaN         NaN         NaN          NaN         NaN
# 4         NaN         NaN         NaN         NaN          NaN         NaN
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# ...

# %%
df.mean()
# Out:
# Points          3.596563
# Score           3.217250
# Weigh          17.848750
# Unnamed: 4     18.600000
# Unnamed: 5     18.600000
# Unnamed: 6     18.600000
# Unnamed: 7     18.600000
# Unnamed: 8     18.600000
# Unnamed: 9           NaN
# Unnamed: 10          NaN
# dtype: float64

# %%
df.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh  Unnamed: 4  Unnamed: 5  \
# 0           AMC Javelin    3.07   3.44  17.02        18.6        18.6
# 1    Cadillac Fleetwood    3.92    NaN  18.90         NaN         NaN
# 2            Camaro Z28     NaN    NaN    NaN         NaN         NaN
# 3     Chrysler Imperial     NaN    NaN    NaN         NaN         NaN
# 4            Datsun 710     NaN    NaN    NaN         NaN         NaN
# 5      Dodge Challenger     NaN    NaN    NaN         NaN         NaN
# 6            Duster 360     NaN    NaN    NaN         NaN         NaN
# 7          Ferrari Dino     NaN    NaN    NaN         NaN         NaN
# 8              Fiat 128     NaN    NaN    NaN         NaN         NaN
# 9             Fiat X1-9     NaN    NaN    NaN         NaN         NaN
# 10       Ford Pantera L     NaN    NaN    NaN         NaN         NaN
# 11          Honda Civic     NaN    NaN    NaN         NaN         NaN
# ...

# %%
df.median()
# Out:
# Points          3.69000
# Score           3.21725
# Weigh          17.82000
# Unnamed: 4     18.60000
# Unnamed: 5     18.60000
# Unnamed: 6     18.60000
# Unnamed: 7     18.60000
# Unnamed: 8     18.60000
# Unnamed: 9          NaN
# Unnamed: 10         NaN
# dtype: float64

# %%
df.isnull()
# Out:
#     Unnamed: 0  Points  Score  Weigh  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0        False   False  False  False        True        True        True
# 1        False   False  False  False        True        True        True
# 2        False   False  False  False        True        True        True
# 3        False   False  False  False        True        True        True
# 4        False   False  False  False        True        True        True
# 5        False   False  False  False        True        True        True
# 6        False   False  False  False        True        True        True
# 7        False   False  False  False        True        True        True
# 8        False   False  False  False        True        True        True
# 9        False   False  False  False        True        True        True
# 10       False   False  False  False        True        True        True
# 11       False   False  False  False        True        True        True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   34 non-null     object
#  1   Points       33 non-null     float64
#  2   Score        33 non-null     float64
#  3   Weigh        33 non-null     float64
#  4   Unnamed: 4   1 non-null      float64
#  5   Unnamed: 5   1 non-null      float64
#  6   Unnamed: 6   1 non-null      float64
#  7   Unnamed: 7   1 non-null      float64
#  8   Unnamed: 8   1 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  3 non-null      object
#  12  Unnamed: 12  5 non-null      object
#  13  Unnamed: 13  9 non-null      object
#  14  Unnamed: 14  9 non-null      object
#  15  Unnamed: 15  4 non-null      object
#  16  Unnamed: 16  7 non-null      object
#  17  Unnamed: 17  4 non-null      object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   34 non-null     object
#  1   Points       33 non-null     float64
#  2   Score        33 non-null     float64
#  3   Weigh        33 non-null     float64
#  4   Unnamed: 4   1 non-null      float64
#  5   Unnamed: 5   1 non-null      float64
#  6   Unnamed: 6   1 non-null      float64
#  7   Unnamed: 7   1 non-null      float64
#  8   Unnamed: 8   1 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  3 non-null      object
#  12  Unnamed: 12  5 non-null      object
#  13  Unnamed: 13  9 non-null      object
#  14  Unnamed: 14  9 non-null      object
#  15  Unnamed: 15  4 non-null      object
#  16  Unnamed: 16  7 non-null      object
#  17  Unnamed: 17  4 non-null      object
# ...

# %%
df.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh  Unnamed: 4  Unnamed: 5  \
# 0           AMC Javelin    3.07   3.44  17.02        18.6        18.6
# 1    Cadillac Fleetwood    3.92    NaN  18.90         NaN         NaN
# 2            Camaro Z28     NaN    NaN    NaN         NaN         NaN
# 3     Chrysler Imperial     NaN    NaN    NaN         NaN         NaN
# 4            Datsun 710     NaN    NaN    NaN         NaN         NaN
# 5      Dodge Challenger     NaN    NaN    NaN         NaN         NaN
# 6            Duster 360     NaN    NaN    NaN         NaN         NaN
# 7          Ferrari Dino     NaN    NaN    NaN         NaN         NaN
# 8              Fiat 128     NaN    NaN    NaN         NaN         NaN
# 9             Fiat X1-9     NaN    NaN    NaN         NaN         NaN
# 10       Ford Pantera L     NaN    NaN    NaN         NaN         NaN
# 11          Honda Civic     NaN    NaN    NaN         NaN         NaN
# ...

# %%
df.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh  Unnamed: 4  Unnamed: 5  \
# 0           AMC Javelin    3.07   3.44  17.02        18.6        18.6
# 1    Cadillac Fleetwood    3.92    NaN  18.90         NaN         NaN
# 2            Camaro Z28     NaN    NaN    NaN         NaN         NaN
# 3     Chrysler Imperial     NaN    NaN    NaN         NaN         NaN
# 4            Datsun 710     NaN    NaN    NaN         NaN         NaN
# 5      Dodge Challenger     NaN    NaN    NaN         NaN         NaN
# 6            Duster 360     NaN    NaN    NaN         NaN         NaN
# 7          Ferrari Dino     NaN    NaN    NaN         NaN         NaN
# 8              Fiat 128     NaN    NaN    NaN         NaN         NaN
# 9             Fiat X1-9     NaN    NaN    NaN         NaN         NaN
# 10       Ford Pantera L     NaN    NaN    NaN         NaN         NaN
# 11          Honda Civic     NaN    NaN    NaN         NaN         NaN
# ...

# %%
df.max()
# Out:
# Points          4.930
# Score           5.424
# Weigh          22.900
# Unnamed: 4     18.600
# Unnamed: 5     18.600
# Unnamed: 6     18.600
# Unnamed: 7     18.600
# Unnamed: 8     18.600
# Unnamed: 9        NaN
# Unnamed: 10       NaN
# dtype: float64

# %%
df.min()
# Out:
# Points          2.760
# Score           1.513
# Weigh          14.500
# Unnamed: 4     18.600
# Unnamed: 5     18.600
# Unnamed: 6     18.600
# Unnamed: 7     18.600
# Unnamed: 8     18.600
# Unnamed: 9        NaN
# Unnamed: 10       NaN
# dtype: float64

# %%
df.kurtosis()
# Out:
# Points        -0.365376
# Score          0.524206
# Weigh          0.984206
# Unnamed: 4          NaN
# Unnamed: 5          NaN
# Unnamed: 6          NaN
# Unnamed: 7          NaN
# Unnamed: 8          NaN
# Unnamed: 9          NaN
# Unnamed: 10         NaN
# dtype: float64

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
